# %%
#loading the required libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\anselmyray'

# %%
# accessing xmy operating stsyem and files storage
import os
print(os.getcwd())
print(os.listdir(os.getcwd()))
# Out:
# C:\Users\anselmyray
# ...

# %%
#Data read from file
salaries=pd.read_csv('salaries_2023.csv')
salaries
# Out:
#       work_year experience_level employment_type                   job_title  \
# 0          2023               MI              FT                 AI Engineer
# 1          2023               MI              FT                Data Manager
# 2          2023               MI              FT                Data Manager
# 3          2023               SE              FT  Machine Learning Scientist
# 4          2023               SE              FT  Machine Learning Scientist
# ...         ...              ...             ...                         ...
# 6770       2020               SE              FT              Data Scientist
# 6771       2021               MI              FT    Principal Data Scientist
# 6772       2020               EN              FT              Data Scientist
# 6773       2020               EN              CT       Business Data Analyst
# 6774       2021               SE              FT        Data Science Manager
#
# ...

# %%
salaries.sort_values(by=['salary_in_usd'],ascending=False)
# Out:
#       work_year experience_level employment_type  \
# 6557       2020               MI              FT
# 5069       2022               MI              FT
# 3069       2023               MI              FT
# 6767       2021               MI              FT
# 3597       2023               SE              FT
# ...         ...              ...             ...
# 1302       2023               MI              FT
# 3252       2020               EX              FT
# 1041       2022               MI              FT
# 6177       2022               EN              FT
# 5880       2021               EN              FT
#
#                                job_title   salary salary_currency  \
# 6557                  Research Scientist   450000             USD
# 5069                        Data Analyst   350000             GBP
# 3069                  Analytics Engineer   350000             GBP
# 6767  Applied Machine Learning Scientist   423000             USD
# ...

# %%
#Top 10 job titles earners by salary in usd. Highest salary earners in USD by Job titles
salaries_high=salaries[['job_title','salary_in_usd']]
salaries_high.nlargest(10,'salary_in_usd')
# Out:
#                                job_title  salary_in_usd
# 6557                  Research Scientist         450000
# 5069                        Data Analyst         430967
# 3069                  Analytics Engineer         430640
# 6767  Applied Machine Learning Scientist         423000
# 3597                        AI Scientist         417937
# 6702            Principal Data Scientist         416000
# 6770                      Data Scientist         412000
# 6500                 Data Analytics Lead         405000
# 2299       Analytics Engineering Manager         399880
# 1627           Machine Learning Engineer         392000

# %%
salaries_high.nlargest(5,'salary_in_usd').plot(kind='bar',figsize=(20,10),fontsize=17,x='job_title',y='salary_in_usd',color=['brown','red','grey','green','cyan'])
plt.ylabel('Salary in USD',fontsize=15)
plt.xlabel('Job Title',fontsize=15)
plt.title('TOP 5 SALARY EARNERS BY JOB TITLE',fontsize=20)
# Out:
# Text(0.5, 1.0, 'TOP 5 SALARY EARNERS BY JOB TITLE')

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
salaries.shape
# Out:
# (6775, 11)

# %%
salaries.describe(include='all')
# Out:
#           work_year experience_level employment_type      job_title  \
# count   6775.000000             6775            6775           6775
# unique          NaN                4               4            117
# top             NaN               SE              FT  Data Engineer
# freq            NaN             4862            6734           1660
# mean    2022.659779              NaN             NaN            NaN
# std        0.594581              NaN             NaN            NaN
# min     2020.000000              NaN             NaN            NaN
# 25%     2022.000000              NaN             NaN            NaN
# 50%     2023.000000              NaN             NaN            NaN
# 75%     2023.000000              NaN             NaN            NaN
# max     2023.000000              NaN             NaN            NaN
#
#               salary salary_currency  salary_in_usd employee_residence  \
# count   6.775000e+03            6775    6775.000000               6775
# ...

# %%
dup_sal=salaries[salaries.duplicated()]
print('Number of duplicated rows;',dup_sal.shape)
# Out:
# Number of duplicated rows; (2652, 11)

# %%
salaries.count()
# Out:
# work_year             6775
# experience_level      6775
# employment_type       6775
# job_title             6775
# salary                6775
# salary_currency       6775
# salary_in_usd         6775
# employee_residence    6775
# remote_ratio          6775
# company_location      6775
# company_size          6775
# dtype: int64

# %%
#drop duplicates in my data
salaries=salaries.drop_duplicates()
salaries.count()
# Out:
# work_year             4123
# experience_level      4123
# employment_type       4123
# job_title             4123
# salary                4123
# salary_currency       4123
# salary_in_usd         4123
# employee_residence    4123
# remote_ratio          4123
# company_location      4123
# company_size          4123
# dtype: int64

# %%
#find null values
print(salaries.isnull().sum())
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2023               MI              FT                 AI Engineer
# 1       2023               MI              FT                Data Manager
# 2       2023               MI              FT                Data Manager
# 3       2023               SE              FT  Machine Learning Scientist
# 4       2023               SE              FT  Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  140000             USD         140000                 US           100
# 1  130000             USD         130000                 US             0
# 2  100000             USD         100000                 US             0
# 3  163800             USD         163800                 US             0
# 4  126000             USD         126000                 US             0
#
#   company_location company_size
# 0               US            S
# ...

# %%
# company size analysis
salaries.company_size.value_counts()
# Out:
# M    3485
# L     479
# S     159
# Name: company_size, dtype: int64

# %%
#analysis of employment type
salaries.employment_type.value_counts()
# Out:
# FT    4082
# CT      17
# PT      13
# FL      11
# Name: employment_type, dtype: int64

# %%
#analysis of workers work year
salaries.work_year.value_counts()
# Out:
# 2023    2723
# 2022    1111
# 2021     216
# 2020      73
# Name: work_year, dtype: int64

# %%
#Bar Chart showing the Number of workers employed per year
salaries.work_year.value_counts().plot(kind='bar',figsize=(10,7), fontsize=15,color=['gold','navy','lime','olive'])
plt.title('Number of workers employed per year',fontsize=20)
plt.xlabel('Work/Employment year',fontsize=17)
plt.ylabel('Number of workers',fontsize=17)
# Out:
# Text(0, 0.5, 'Number of workers')

# %%
salaries.experience_level.value_counts()
# Out:
# SE    2652
# MI     976
# EN     327
# EX     168
# Name: experience_level, dtype: int64

# %%
#PIE CHART SHOWING PERCENTAGE OF EXPERIENCE LEVEL
salaries.experience_level.value_counts().plot(kind='pie',figsize=(10,10),autopct='%0.1f%%',legend=['SE','MI','EN','EX'],fontsize=20)
plt.title('PIE CHART SHOWING PERCENTAGE OF WORKERS EXPERIENCE LEVEL',fontsize=15)
# Out:
# Text(0.5, 1.0, 'PIE CHART SHOWING PERCENTAGE OF WORKERS EXPERIENCE LEVEL')

# %%
#Number of company locations per country(Top 10)
salaries.company_location.value_counts().nlargest(10)
# Out:
# US    3200
# GB     286
# CA     142
# DE      69
# ES      56
# IN      48
# FR      45
# AU      21
# PT      17
# BR      17
# Name: company_location, dtype: int64

# %%
#Line Chart showing number of company locations per country(Top 5)
salaries.company_location.value_counts().nlargest(5).plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
#Top 15 job titles
salaries.job_title.value_counts().nlargest(15)
# Out:
# Data Engineer                     888
# Data Scientist                    805
# Data Analyst                      598
# Machine Learning Engineer         376
# Analytics Engineer                167
# Research Scientist                121
# Data Architect                     92
# Research Engineer                  74
# ML Engineer                        73
# Data Science Manager               66
# Applied Scientist                  64
# Machine Learning Scientist         45
# Data Manager                       41
# Business Intelligence Engineer     32
# Data Science Consultant            31
# Name: job_title, dtype: int64

# %%
# bar chart showing top 15 job titles
salaries.job_title.value_counts().nlargest(15).plot(kind='barh',figsize=(20,10),fontsize=25,color=['green','red','black','blue','orange','purple','cyan','yellow','violet','pink','grey','lime','brown','olive','magenta'])
plt.title('Bar Chart showing the Top 15 Job titles',fontsize=40)
plt.xlabel('Number of persons',fontsize=30)
plt.ylabel('Job title',fontsize=30)
# Out:
# Text(0, 0.5, 'Job title')

# %%
salaries['company_size'].unique()
# Out:
# array(['S', 'M', 'L'], dtype=object)

# %%
#PIE CHART SHOWING PERCENTAGE OF COMPANY SIZES
explode=(0.1,0,0)
salaries.company_size.value_counts().plot(kind='pie',figsize=(10,10),autopct='%0.1f%%',legend=['M','S','L'],fontsize=20,explode=explode,shadow=True,startangle=10)
plt.title('PIE CHART SHOWING PERCENTAGE OF COMPANY SIZES-(SMALL,MEDIUM AND LARGE)',fontsize=15)
# Out:
# Text(0.5, 1.0, 'PIE CHART SHOWING PERCENTAGE OF COMPANY SIZES-(SMALL,MEDIUM AND LARGE)')

# %% [markdown]
# # ANALYSING DATA FOR US LOCATION

# %%
#Details for company locations based in US
US=salaries[salaries['company_location']=='US']
US
# Out:
#       work_year experience_level employment_type                   job_title  \
# 0          2023               MI              FT                 AI Engineer
# 1          2023               MI              FT                Data Manager
# 2          2023               MI              FT                Data Manager
# 3          2023               SE              FT  Machine Learning Scientist
# 4          2023               SE              FT  Machine Learning Scientist
# ...         ...              ...             ...                         ...
# 6769       2021               SE              FT             Data Specialist
# 6770       2020               SE              FT              Data Scientist
# 6771       2021               MI              FT    Principal Data Scientist
# 6772       2020               EN              FT              Data Scientist
# 6773       2020               EN              CT       Business Data Analyst
#
# ...

# %%
#job titles with the highest number of workers in US
US['job_title'].value_counts()
# Out:
# Data Engineer                          712
# Data Scientist                         620
# Data Analyst                           488
# Machine Learning Engineer              284
# Analytics Engineer                     140
#                                       ...
# Finance Data Analyst                     1
# Principal Machine Learning Engineer      1
# Manager Data Management                  1
# Staff Machine Learning Engineer          1
# Principal Data Analyst                   1
# Name: job_title, Length: 94, dtype: int64

# %%
UK=US[['job_title','salary_in_usd']]
UK
# Out:
#                        job_title  salary_in_usd
# 0                    AI Engineer         140000
# 1                   Data Manager         130000
# 2                   Data Manager         100000
# 3     Machine Learning Scientist         163800
# 4     Machine Learning Scientist         126000
# ...                          ...            ...
# 6769             Data Specialist         165000
# 6770              Data Scientist         412000
# 6771    Principal Data Scientist         151000
# 6772              Data Scientist         105000
# 6773       Business Data Analyst         100000
#
# [3200 rows x 2 columns]

# %%
US_HIGH=UK.sort_values(by=['salary_in_usd'],ascending=False)
US_HIGH.head()
# Out:
#                                job_title  salary_in_usd
# 6557                  Research Scientist         450000
# 6767  Applied Machine Learning Scientist         423000
# 6702            Principal Data Scientist         416000
# 6770                      Data Scientist         412000
# 6500                 Data Analytics Lead         405000

# %%
US['work_year'].value_counts()
# Out:
# 2023    2225
# 2022     844
# 2021      98
# 2020      33
# Name: work_year, dtype: int64

# %%
US['experience_level'].value_counts()
# Out:
# SE    2268
# MI     604
# EN     189
# EX     139
# Name: experience_level, dtype: int64

# %%
US['company_size'].value_counts()
# Out:
# M    2876
# L     261
# S      63
# Name: company_size, dtype: int64

# %%
US['employment_type'].value_counts()
# Out:
# FT    3179
# CT      13
# PT       4
# FL       4
# Name: employment_type, dtype: int64

# %%
salaries_data=salaries.pivot_table(index=['experience_level','company_size'],values='company_location',aggfunc='count')
salaries_data
# Out:
#                                company_location
# experience_level company_size
# EN               L                           97
#                  M                          184
#                  S                           46
# EX               L                           17
#                  M                          143
#                  S                            8
# MI               L                          154
#                  M                          766
#                  S                           56
# SE               L                          211
#                  M                         2392
#                  S                           49

# %%
salaries_data.plot(kind='line',figsize=(10,5),lw=5,linestyle=':')
# Out:
# <AxesSubplot:xlabel='experience_level,company_size'>

# %%
salaries_datar=salaries.pivot_table(index=['company_location','work_year'],values='experience_level',aggfunc='count')
salaries_datar.nlargest(10,'experience_level')
# Out:
#                             experience_level
# company_location work_year
# US               2023                   2225
#                  2022                    844
# GB               2023                    192
# US               2021                     98
# CA               2023                     93
# GB               2022                     75
# CA               2022                     36
# US               2020                     33
# ES               2023                     31
# DE               2023                     27

# %%
salaries_datar.nlargest(5,'experience_level').plot(kind='bar',figsize=(20,10),fontsize=15)
# Out:
# <AxesSubplot:xlabel='company_location,work_year'>

# %%
salaries_datar.nlargest(10,'experience_level').plot(kind='bar',figsize=(20,10),fontsize=15)
# Out:
# <AxesSubplot:xlabel='company_location,work_year'>

# %%
#Details for company locations based in US
US=salaries[salaries['company_location']=='GB']
US
# Out:
#       work_year experience_level employment_type             job_title  \
# 35         2023               MI              FT          Data Analyst
# 36         2023               MI              FT          Data Analyst
# 101        2023               MI              FT         Data Engineer
# 102        2023               MI              FT         Data Engineer
# 268        2023               MI              FT         Data Engineer
# ...         ...              ...             ...                   ...
# 6706       2021               MI              FT        Data Scientist
# 6709       2020               SE              FT     Big Data Engineer
# 6716       2021               MI              FT         Data Engineer
# 6737       2021               SE              FT  Finance Data Analyst
# 6738       2021               SE              FT         Data Engineer
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
US.sort_values(by=['salary_in_usd'],ascending=False)
# Out:
#       work_year experience_level employment_type  \
# 5069       2022               MI              FT
# 3069       2023               MI              FT
# 2299       2023               SE              FT
# 1787       2023               MI              FT
# 3016       2023               SE              FT
# ...         ...              ...             ...
# 6279       2022               MI              FT
# 6235       2022               MI              FT
# 6231       2022               EN              FT
# 5624       2022               EN              FT
# 6133       2022               EN              FT
#
#                           job_title  salary salary_currency  salary_in_usd  \
# 5069                   Data Analyst  350000             GBP         430967
# 3069             Analytics Engineer  350000             GBP         430640
# 2299  Analytics Engineering Manager  325000             GBP         399880
# ...

# %%
salaries.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'work_year'}>,
#         <AxesSubplot:title={'center':'salary'}>],
#        [<AxesSubplot:title={'center':'salary_in_usd'}>,
#         <AxesSubplot:title={'center':'remote_ratio'}>]], dtype=object)

# %%
sns.boxplot(x='work_year',y='employment_type',data=salaries)
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='employment_type'>

# %%
sns.pairplot(salaries)

# %%
plt.figure(figsize=(20,10))
s=salaries.corr()
sns.heatmap(s,cmap="BrBG",annot=True)
s
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.098046       0.214178     -0.184852
# salary         -0.098046  1.000000      -0.015527      0.023008
# salary_in_usd   0.214178 -0.015527       1.000000     -0.106385
# remote_ratio   -0.184852  0.023008      -0.106385      1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(salaries_datar.nlargest(5,'experience_level'),cmap="BrBG",annot=True)
# Out:
# <AxesSubplot:ylabel='company_location-work_year'>

# %%
# Ensure 'salary_in_usd' is numeric
salaries['salary_in_usd'] = pd.to_numeric(salaries['salary_in_usd'], errors='coerce')

# Drop rows where salary could not be converted to numeric values
salaries = salaries.dropna(subset=['salary_in_usd'])
# Out:
# C:\Users\anselmyray\AppData\Local\Temp\ipykernel_15292\742430002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salaries['salary_in_usd'] = pd.to_numeric(salaries['salary_in_usd'], errors='coerce')

# %%
# Group by job_title and calculate the average salary
average_salary_by_job = salaries.groupby('job_title')['salary_in_usd'].mean().reset_index()

# Sort by salary in descending order
top_15_jobs = average_salary_by_job.sort_values(by='salary_in_usd', ascending=False).head(15)
top_15_jobs
# Out:
#                               job_title  salary_in_usd
# 8         Analytics Engineering Manager  399880.000000
# 62               Data Science Tech Lead  375000.000000
# 98       Managing Director Data Science  300000.000000
# 6                    AWS Data Architect  258000.000000
# 26                 Cloud Data Architect  250000.000000
# 0                          AI Architect  237484.000000
# 73             Director of Data Science  207221.238095
# 86                          ML Engineer  194172.232877
# 106            Principal Data Scientist  193988.444444
# 95   Machine Learning Software Engineer  189538.769231
# 78                         Head of Data  186627.157895
# 116     Staff Machine Learning Engineer  185000.000000
# 12                    Applied Scientist  183996.343750
# 60                 Data Science Manager  178955.015152
# 79                 Head of Data Science  178387.250000

# %%
# Set up the plot
plt.figure(figsize=(10, 6))
sns.barplot(x='salary_in_usd', y='job_title', data=top_15_jobs, palette='viridis')

# Add titles and labels
plt.title('Top 15 Job Titles by Average Salary in USD', fontsize=14)
plt.xlabel('Average Salary (USD)', fontsize=12)
plt.ylabel('Job Title', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Plotting Experience Level by Company Size
plt.figure(figsize=(10, 6))
sns.countplot(data=salaries, x='company_size', hue='experience_level', palette='Set1')

# Add titles and labels
plt.title('Experience Level by Company Size', fontsize=14)
plt.xlabel('Company Size', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Plotting Experience Level by Work Year
plt.figure(figsize=(10, 6))
sns.countplot(data=salaries, x='work_year', hue='experience_level', palette='Set2')

# Add titles and labels
plt.title('Experience Level by Work Year', fontsize=14)
plt.xlabel('Work Year', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by company_location and calculate average salary in USD
top_locations_salary = salaries.groupby('company_location')['salary_in_usd'].mean().reset_index()

# Sort by average salary in descending order and select the top 10 locations
top_10_locations = top_locations_salary.sort_values(by='salary_in_usd', ascending=False).head(10)

# Plotting the top 10 locations by average salary
plt.figure(figsize=(12, 6))
sns.barplot(x='salary_in_usd', y='company_location', data=top_10_locations, palette='coolwarm')

# Add titles and labels
plt.title('Top 10 Locations by Highest Average Salary in USD', fontsize=14)
plt.xlabel('Average Salary (USD)', fontsize=12)
plt.ylabel('Company Location', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 2. Experience level and employment type by work year
plt.figure(figsize=(10, 8))
sns.countplot(data=salaries, x='work_year', hue='experience_level', palette='coolwarm', dodge=True)
plt.title('Experience Level by Work Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.legend(title='Experience Level')
plt.show()

plt.figure(figsize=(10, 8))
sns.countplot(data=salaries, x='work_year', hue='employment_type', palette='Set2', dodge=True)
plt.title('Employment Type by Work Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.legend(title='Employment Type')
plt.show()

# %%
# 3. Company size by year
company_size_by_year = salaries.groupby(['work_year', 'company_size']).size().reset_index(name='count')
plt.figure(figsize=(10, 8))
sns.barplot(data=company_size_by_year, x='work_year', y='count', hue='company_size', palette='Set3')
plt.title('Company Size by Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.legend(title='Company Size')
plt.show()

# %%
# 4. Top 5 job titles by year
def get_top_5_jobs_by_year(salaries):
    top_jobs_by_year = []
    for year in salaries['work_year'].unique():
        yearly_data = salaries[salaries['work_year'] == year]
        top_5_jobs = (yearly_data['job_title']
                      .value_counts()
                      .head(5)
                      .reset_index())
        top_5_jobs['work_year'] = year
        top_5_jobs.columns = ['job_title', 'count', 'work_year']
        top_jobs_by_year.append(top_5_jobs)
    return pd.concat(top_jobs_by_year, ignore_index=True)

top_jobs_by_year = get_top_5_jobs_by_year(salaries)
plt.figure(figsize=(12, 8))
sns.barplot(data=top_jobs_by_year, x='work_year', y='count', hue='job_title', palette='Paired')
plt.title('Top 5 Job Titles by Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.legend(title='Job Title')
plt.show()

# %%
# 5. Top 3 company locations by year
def get_top_3_locations_by_year(salaries):
    top_locations_by_year = []
    for year in salaries['work_year'].unique():
        yearly_data = salaries[salaries['work_year'] == year]
        top_3_locations = (yearly_data['company_location']
                           .value_counts()
                           .head(3)
                           .reset_index())
        top_3_locations['work_year'] = year
        top_3_locations.columns = ['company_location', 'count', 'work_year']
        top_locations_by_year.append(top_3_locations)
    return pd.concat(top_locations_by_year, ignore_index=True)

top_locations_by_year = get_top_3_locations_by_year(salaries)
plt.figure(figsize=(12, 8))
sns.barplot(data=top_locations_by_year, x='work_year', y='count', hue='company_location', palette='Spectral')
plt.title('Top 3 Company Locations by Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.legend(title='Company Location')
plt.show()

# %%
# 6. Predict salary trends for the next 5 years
# Prepare the data for the model
from sklearn.linear_model import LinearRegression
salary_trends = salaries.groupby('work_year')['salary_in_usd'].mean().reset_index()
X = salary_trends['work_year'].values.reshape(-1, 1)
y = salary_trends['salary_in_usd'].values

# Train a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict the next 5 years
future_years = np.array(range(salaries['work_year'].max() + 1, salaries['work_year'].max() + 6)).reshape(-1, 1)
predicted_salaries = model.predict(future_years)

# Combine past and predicted data
future_data = pd.DataFrame({'work_year': future_years.flatten(), 'salary_in_usd': predicted_salaries})
combined_data = pd.concat([salary_trends, future_data], ignore_index=True)

# Plot the trends
plt.figure(figsize=(10, 6))
sns.lineplot(data=combined_data, x='work_year', y='salary_in_usd', marker='o', label='Salary Trend')
plt.title('Salary Trends (Past and Predicted)')
plt.xlabel('Year')
plt.ylabel('Average Salary (USD)')
plt.legend()
plt.show()

# %%
# 6. Predict salary trends for the next 5 years based on top 5 job titles with highest average salary
# Identify the top 5 job titles with the highest average salary
top_5_jobs = (salaries.groupby('job_title')['salary_in_usd']
               .mean()
               .sort_values(ascending=False)
               .head(5)
               .index)

# Filter the dataset for the top 5 job titles
filtered_salaries = salaries[salaries['job_title'].isin(top_5_jobs)]

# Group by year and calculate the average salary for these job titles
salary_trends_top_jobs = (filtered_salaries.groupby('work_year')['salary_in_usd']
                          .mean()
                          .reset_index())

X_top_jobs = salary_trends_top_jobs['work_year'].values.reshape(-1, 1)
y_top_jobs = salary_trends_top_jobs['salary_in_usd'].values

# Train a linear regression model
model_top_jobs = LinearRegression()
model_top_jobs.fit(X_top_jobs, y_top_jobs)

# Predict the next 5 years
future_years_top_jobs = np.array(range(salaries['work_year'].max() + 1, salaries['work_year'].max() + 6)).reshape(-1, 1)
predicted_salaries_top_jobs = model_top_jobs.predict(future_years_top_jobs)

# Combine past and predicted data
future_data_top_jobs = pd.DataFrame({'work_year': future_years_top_jobs.flatten(), 'salary_in_usd': predicted_salaries_top_jobs})
combined_data_top_jobs = pd.concat([salary_trends_top_jobs, future_data_top_jobs], ignore_index=True)

# Plot the trends
plt.figure(figsize=(10, 6))
sns.lineplot(data=combined_data_top_jobs, x='work_year', y='salary_in_usd', marker='o', label='Salary Trend for Top 5 Job Titles')
plt.title('Salary Trends for Top 5 Job Titles (Past and Predicted)')
plt.xlabel('Year')
plt.ylabel('Average Salary (USD)')
plt.legend()
plt.show()
